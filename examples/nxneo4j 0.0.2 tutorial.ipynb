# %% [markdown]
# ## 0.0.1 vs 0.0.2

# %% [markdown]
# 0.0.2 basically resurrects nxneo4j:
# - All "apoc" based code is moved to Graph Data Science library aka "gds" since apoc is not supported by neo4j 4x
# - All {params} syntax moved to $params syntax since {params} no longer supported
# - Added nxneo4j.Graph.delete_all() feature for quick deleting of the data
# - Added nxneo4j.Graph.load_got(), nxneo4j.Graph.load_twitter(), nxneo4j.Graph.load_euroads() for quick data installation
#
# Requirements:
# - ≥ Neo4j 4.x
# - Graph Data Science Library Plugin
# - APOC Plugin
# - ≥ Python 3.6
# - ≥ neo4j-driver 4.x
#
# KNOWN ISSUES IN 0.0.2:
# - nxneo4j.Graph.load_got(), nxneo4j.Graph.load_twitter(), nxneo4j.Graph.load_euroads() gives Contraint error and toInt no longer used errors. Fixed on 0.0.3
# - nxneo4j.betweenness_centrality(G) throws ClientError. Fixed on 0.0.3
# - nxneo4j.pagerank(G) throws TransientError: Database 'neo4j' unavailable
# - nx.triangles(G) throws ClientError. Fixed on 0.0.3
# - nx.clustering(G) throws ClientError. Fixed on 0.0.3

# %% [markdown]
# ## Connect to Neo4j

# %% [markdown]
# STOP! Make sure you have actually started Neo4j. If the Neo4j is not already running there is nothing to connect to

# %%
from neo4j import GraphDatabase

# %%
driver = GraphDatabase.driver(uri="bolt://localhost:11003",auth=("neo4j","your_password"))
                              #OR "bolt://localhost:7673"
                              #OR the cloud url

# %% [markdown]
# ## Import nxneo4j
#
# If not already installed, install the latest version like this:

# %%
! pip install networkx-neo4j==0.0.2
# Out:
# Requirement already satisfied: networkx-neo4j==0.0.2 in /opt/anaconda3/lib/python3.7/site-packages (0.0.2)
# Requirement already satisfied: neo4j-driver in /opt/anaconda3/lib/python3.7/site-packages (from networkx-neo4j==0.0.2) (4.0.0a4)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.7/site-packages (from neo4j-driver->networkx-neo4j==0.0.2) (2019.3)

# %% [markdown]
# Otherwise, follow:

# %%
import nxneo4j as nx

# %%
G = nx.Graph(driver)

# %%
G.delete_all()  #BE CAREFUL! This will delete all the data.
                #By deleting, just making sure that the results are reprodusible.

# %% [markdown]
# ## Add Nodes

# %%
#Add a node
G.add_node(1)

# %%
#Add multiple nodes as once
G.add_nodes_from([1,2,3,4])

# %% [markdown]
# ## Add Edges

# %%
#Add one edge
G.add_edge(1,2)

# %%
#Add multiple edges
G.add_edges_from([(1,2),(3,4)])

# %% [markdown]
# ## Graph Data Science

# %%
G.delete_all()

# %%
G.load_twitter()

# %%
#You can change the default parameters like the following:
G.identifier_property = 'username'
G.relationship_type = 'FOLLOWS'
G.node_label = 'User'

# %%
nx.shortest_path(G, source='markhneedham', target='businessinsider')
# Out:
# ['markhneedham', 'nunenuh', 'businessinsider']

# %%
list(nx.community.label_propagation_communities(G))
# Out:
# [{'ng28softball'},
#  {'frant_hartm',
#   'joebew42',
#   '_JustinMoon_',
#   'antirez',
#   'LBacaj',
#   'mmetzger',
#   'ClhoHuerta',
#   'NickLuallin',
#   'PatOSullivanIBM',
#   'tomahock',
#   'fricau',
#   'PerWiklander',
#   'rautsan',
#   'ryantzj',
#   'Talend',
#   'develaper',
#   'rMdes_',
#   'rrrouyer',
#   'teoseller',
#   'noduslabs',
#   'alanlepo',
#   'Techforce1_nl',
#   'debugwand',
#   'h_oll',
#   'triptych',
#   'maker_iot_tr',
#   'DCI_Resources',
#   'alfonsodg',
#   'tahsin_mayeesha',
#   'irregularbi',
#   'clr_bnrd',
#   'JavaUnofficial',
#   'JeffreyAStewart',
#   'thoughtbot',
#   'kwyxz',
#   'jonathanhartsf',
#   'EzraSandzer',
#   'sldatacommunity',
#   'rimllr',
#   'brockjelmore',
#   'PatrickVMadden',
#   'TechedgeEs',
#   'Arzhanger',
#   'The_Zach_West',
#   'TomasKazmierski',
#   'rahulattuluri',
#   'doctor_cerulean',
#   'CluedInSeymour',
#   'h_ingo',
#   'dan_mcclary',
#   'mariuskarma',
#   'SokanAcademy',
#   'PieterCoussemen',
#   'Jc_ArtsCase',
#   'ShivaRe69882994',
#   'mags_ft',
#   'John_cena610',
#   'Loguteva',
#   'dripsandcastle',
#   'cottinstef',
#   'zodda',
#   'z3r0cool',
#   'TT_SemWeb',
#   'fzakariya',
#   's7ephen',
#   'Talenders',
#   'BeyondSearch',
#   'john_crocker',
#   'DannyCrichton',
#   'hackernewsfeed',
#   'InformatiqNews',
#   'MagemelloMario',
#   'kellyfj1',
#   'eoolsen',
#   'SeunMatt2',
#   'seldo',
#   'BLACKCERT',
#   'pwesterman',
#   'BrunoUngermann',
#   'satRdayParis',
#   'fblamanna',
#   'cmcd_phd',
#   'Fingent',
#   'akngw',
#   'AndrewFrater',
#   'SparsityTech',
#   'FrankVullers',
#   'oss_js',
#   'brianhurley',
#   'KMWorld',
#   'allangoode',
#   'dimoskoptsis',
#   'itscyberinject',
#   'arcreativenet',
#   'DavidNind',
#   'webpoint_new',
#   'GandhinagarNews',
#   'ItsMeijers',
#   'digitalenergyj',
#   'nickparsons',
#   'Kuujikai',
#   'raevilman',
#   'ashish_fagna',
#   'vastur',
#   'mirandakaywebb1',
#   'miguelinlas3',
#   'Cyril__',
#   'davidgasquez',
#   'blitznihar',
#   'GitHaiku',
#   'darshitj2',
#   'onlydatajobs',
#   'msbicoe',
#   'RMSite',
#   'thesilverlogic',
#   'tekiegirl',
#   'yennwolf',
#   'logly',
#   'BecomingDataSci',
#   'lilachmanheim',
#   'reseauloops',
#   'frankmcsherry',
#   'showmesolutions',
#   'StephanGils',
#   'stevedischinger',
#   'betterhn100',
#   'monah1711',
#   'kingrockie',
#   'appareto',
#   'codepitbull',
#   'alisovino',
#   'fabiogomezdiaz',
#   'carlesdijous',
#   'sqlenergy',
#   'bookwatchiprog',
#   'taswarbhatti',
#   'alexpospiech',
#   'rtehrani',
#   'krislerok',
#   'SFEIR',
#   'dstepp2',
#   'cddigitalorg',
#   'lulufrego',
#   'StevenXi07',
#   'menomeTech',
#   'Harkediansa',
#   'jbfavre',
#   'jackzimmerman',
#   'jamesharrison',
#   'TridzOnline',
#   'clojurenorth',
#   'waugoola',
#   'franse15',
#   'EricPBloom',
#   'aloksha',
#   'ElffarAnalytics',
#   'ShowHNDaily',
#   'carlosguadian',
#   'tistre',
#   'red_nodes',
#   'marie_alexb',
#   'ActianCorp',
#   'daye_nam',
#   'devtoolsdigest',
#   'ripienaar',
#   'hiteshgondalia',
#   'DavidSolesP',
#   'radityopw',
#   'Mareike2405',
#   'aureliengeorget',
#   'lukoerfer',
#   'bigdataparis',
#   'farashod',
#   'runnersbyte',
#   'tedvga',
#   'InfoProNetwork',
#   'interviewgig',
#   'DocQLio',
#   'CHardyG2',
#   'Harjunmaa',
#   'CLGAnalytics',
#   'SQL_Doch',
#   'WhaleHoss',
#   'chidambara09',
#   'Srijan',
#   'certosatweets',
#   'MarieGirardChop',
#   'M157q_News_RSS',
#   'realmgic',
#   'enova',
#   'ucfgeek',
#   'iGenomics',
#   'chefhans',
#   'ashdiscovers',
#   '_ColinFay',
#   'kukharenko',
#   'quanderio',
#   'aaronzollman',
#   'sheislaurence',
#   'bk1_168',
#   'AvolutionAbacus',
#   'sumits_kumar',
#   'nikimari',
#   'alister_b',
#   'Ken_Yamamura',
#   'EbertFabi',
#   'Virtumente',
#   'danielcfng',
#   'RetweetedRajeev',
#   'jizaymes',
#   'hannes_lowette',
#   'Azn_CyberSleuth',
#   'CYxChris',
#   'HeyChelseaTroy',
#   'jmsunico',
#   'AnalyticExec',
#   'SwissCognitive',
#   'ldellaquila',
#   'jai_prasad17',
#   'stanleysuen',
#   'Pouncey17',
#   'willricketts',
#   'RupprechtMaria',
#   'dahowlett',
#   'niazjalal',
#   'Social_Cops',
#   '0p4r3t0r',
#   'grep_kaustubh',
#   'MoneyhealthF',
#   'nelumihai',
#   'IdentityMonk',
#   'kevvurs',
#   'colinbarker19',
#   'Adron',
#   'techjunkiejh',
#   'startupsucht',
#   'GLEIF',
#   'Going_Digital30',
#   'DATANOMIQ',
#   'zkancs',
#   'patbaumgartner',
#   'amarghuman',
#   'GraphQLatSO',
#   'LucknowNews',
#   'pwsh_guy',
#   'NodeXL_Mktng',
#   'metaincognito',
#   'CecileHbh',
#   'l1formaticien',
#   'bjoernoest',
#   'certifiedwaif',
#   'namerson5',
#   'BenListyg',
#   'LisaAnneBraun',
#   'jimwebber',
#   'turley714',
#   'davib0',
#   'kvasnica',
#   'HalbaradKenafin',
#   'andigutmans',
#   'AsISeeTech',
#   'luiy',
#   'corbanb',
#   'leviw',
#   'nschaetti',
#   'AndrewMBaker',
#   'euranova',
#   'gscalingacademy',
#   'maruyama3',
#   'floorter',
#   'JonnyDubowsky',
#   'dutradotdev',
#   'aschauerhuber',
#   'brunoborges',
#   'VizMatt',
#   'JonoHeher',
#   'noservershere',
#   'ira_res',
#   'dariospagnolo',
#   'Indiaitfirms',
#   'CoreDumpConf',
#   'andrewbain',
#   'ai_community',
#   'SQLDoubleG',
#   'maxdalmas',
#   'DvKlopfenstein',
#   'w0nvel',
#   'sadsaviour',
#   'CMR_ExecAdv',
#   'Decideo',
#   'michvictor',
#   'herahussain',
#   'ziniman',
#   'paulmiller99',
#   'ThomasG77',
#   'grapheverywhere',
#   'ykarikos',
#   'solidbrokers',
#   'xagronaut',
#   'mySocializerHub',
#   'GraphXr',
#   'IAP_Networking',
#   'iange',
#   'MailpicksU',
#   'OutCoastIt',
#   'b0rb0SS',
#   'ronald_istos',
#   'jk8172',
#   'SRoyLee',
#   'Webseo69',
#   'hpdailyrant',
#   'CourseGift',
#   'jugsummercamp',
#   'GQAdonisCTO',
#   'nmcl',
#   'nthnryn',
#   'Manali_MTS',
#   'batoolchishti92',
#   'simondachstr',
#   'Desk_Rider',
#   'agentGav',
#   'stevenamapes',
#   'KoyO_JakaNeEs',
#   'danielg0ldberg',
#   'Azure',
#   'mcohmi',
#   'JeremyCoxCAE',
#   'NYDF_Platform',
#   'c_z',
#   'doggoit',
#   'dvirsky',
#   'JeremyMorrell',
#   'etsinfupv',
#   'SeqComplete',
#   'mcvey_greg',
#   'AyittahBernard',
#   'swagunke',
#   'DinisCruz',
#   'JamesFlint',
#   'kasia_git',
#   'bigdata',
#   'Surgisse',
#   'anteos',
#   'Antonio23132075',
#   'StackDevJobs',
#   'j3mbe',
#   'statsprovenutn',
#   'blm849',
#   'ArchBeatDev',
#   'arlynculwick',
#   'GA',
#   'DrStrange_Bot',
#   'node_stack',
#   'MGazanayi',
#   'learnNoSql',
#   'BinaryMuse',
#   'StepsizeHQ',
#   'Marc_Pou',
#   'ChrisKa52931839',
#   'AcaymoNM',
#   'pgxn',
#   'davidrapin',
#   'minhphien',
#   'lordmj',
#   'msgDAVID',
#   'mtmac4',
#   'Steve4years',
#   'hackintoshrao',
#   'scikit_yb',
#   'T0mmySk',
#   'Instacart',
#   'robertopuyo',
#   'Edopeno',
#   'nfigay',
#   'erictummers',
#   'PetroInnovation',
#   'roens',
#   'Neo4jGH',
#   'synyx_ka',
#   'therealdudez',
#   'DigiTechNewsNet',
#   'cb0day',
#   'sdeterme',
#   'elixirforum',
#   'vikrambodke09',
#   'TSchuermans',
#   'st3llasia',
#   'RezaC1',
#   'senzing',
#   'arpit',
#   'AppsCodeHQ',
#   'kirkham_anthony',
#   '_wald0',
#   'AlaMenai',
#   'stefandumont',
#   'sysbus_eu',
#   'DammianMiller',
#   'wangsuya1',
#   'BudapestData',
#   'geeks_db',
#   'jamescummings',
#   'ICBmunich',
#   'samuelroze',
#   'InformaticaC1',
#   'wilsonkriegel',
#   'JetTechnology',
#   'profanegeometry',
#   'Streak',
#   'AlleyWatch',
#   'Python_Links',
#   'daniel_sellers',
#   'manishrjain',
#   'Sheridan_Gerard',
#   'brightopare',
#   'odbmsorg',
#   'munsteriron',
#   'zdnetfr',
#   'LarifariNerdy',
#   'plzbeemyfriend',
#   'TheCloudSumo',
#   'freiksenet',
#   'chpanto',
#   'highscal',
#   'kaisrei',
#   'FroehlichMarcel',
#   'csirac2',
#   'madewithtea',
#   'iamrahuljain_in',
#   'siliconion',
#   'PythonLoop',
#   'RobSeder',
#   'hyperdev_fr',
#   'Real_Time_Data',
#   'rags080484',
#   'PortoData',
#   'PHPStack',
#   'devops_chat',
#   'OntotextGraphDB',
#   'gitbisect',
#   'MobilesAppStore',
#   'RashmiNbr',
#   'westendoerpf',
#   'iam_vee',
#   'AndreasKuczera',
#   'jaedenlove',
#   'HacksHackersBA',
#   'cheeaun',
#   'insight_socio',
#   'eric_kavanagh',
#   'sebclick',
#   'nicokosi',
#   'swinkelstom',
#   'Bh26',
#   'marchoutgraaf',
#   'lordofmisrule',
#   'timanderson',
#   'JRayDenver',
#   'nycallday247',
#   'project_network',
#   'thramp',
#   'KC72576_Tech',
#   'paper_radio',
#   'ardan7779',
#   'Rache1H',
#   'louis_guitton',
#   'iot_ng',
#   'jsalsman',
#   'nabilblk',
#   '_carpenter315',
#   'uber1geek',
#   'mdavidallen',
#   'JAdP',
#   'HarishMinions20',
#   'usepanda',
#   'SeattlesBanker',
#   'oldaily',
#   'node_developer',
#   'binarymachines',
#   'contentspd1',
#   'scottakenhead',
#   'WorkgridSoft',
#   'mscavazzin',
#   'DanielGallagher',
#   'boldingbroke',
#   'makmanalp',
#   'nvfontoy',
#   'jodok',
#   'artbrock',
#   'Neo4jCommunityQ',
#   'fRoldanCordoba',
#   'TimWilliate',
#   'ThatSSR',
#   'nodebuster',
#   'HunterSoluk',
#   '2linuxorg',
#   'basarat',
#   'shivkumarganesh',
#   'PToschka',
#   'semwebcompany',
#   'JosephPitluck',
#   'jaume_olledo',
#   'SQLShark',
#   'amt_jose',
#   'mfauscette',
#   'NovasTaylor',
#   'rstiles16',
#   'SamiraKorani',
#   'stonerichio',
#   'YasserIM',
#   'wednesday099',
#   'CVEnew',
#   'itfmco',
#   'ohubaut',
#   'pdxleif',
#   'learnlinksfeed',
#   'database_camp',
#   'SiGe92',
#   'drimcalban',
#   'cleishm',
#   'jmjhjr',
#   'tek_news',
#   'HEbertKONLABS',
#   'eliaswalyba',
#   'jgxdot',
#   'sypherlev',
#   'cteodor',
#   'werowe',
#   'blubbfiction',
#   'duward',
#   'IanMmmm',
#   'clojuredconf',
#   'dee_bloo',
#   'JavaScript_Plow',
#   'smniemi',
#   'meherfalcon',
#   'PinPopular',
#   'MattWilcox',
#   'Stasoni',
#   'abhishekkgupta',
#   'datao',
#   'The_Code_Shirts',
#   'dspsingh51',
#   'StachuDotNet',
#   'jpfersich',
#   'XLinStrategy',
#   'MohitShrestha',
#   'thisismetis',
#   'SigP226',
#   'eboillat',
#   'thejimhatcher',
#   'KnoxvilleTNJob1',
#   'xeraa',
#   'jcmezagd',
#   'mquinn_100',
#   'qconlondon',
#   'vourcetech',
#   'hughbarnard',
#   'xMAnton',
#   'krbnite',
#   'muntasirJoarder',
#   'dylanomran',
#   'yonkeltron',
#   'carbone',
#   'khazen',
#   'IB0nkers',
#   'PVynckier',
#   'sariladin',
#   'Nik_Anesiadis',
#   'myfear',
#   'badc0da',
#   'voxelbased',
#   'the_nayans',
#   'thebloorgroup',
#   'gunnarmorling',
#   'cramTeXeD',
#   'AISII_UAM',
#   'kbrancewicz',
#   'dysonspherelab',
#   'JavaScriptKicks',
#   'velocimetrics',
#   'fintechsteve',
#   'MatzeOne',
#   'miwillhite',
#   'jepsen_io',
#   'CharlieBurgoyne',
#   'n4stack',
#   'niklas_heer',
#   'rajmatazz',
#   'arinai',
#   'kuriharan',
#   'cyberologue',
#   'DennisFaucher',
#   'hampshire67',
#   'FlorentStorme',
#   'MSPartnerApps',
#   'maldicollo',
#   'caiomsouza',
#   'jm3',
#   'DeVilTechSolns',
#   'giuxma',
#   'nilkad008',
#   'TDKTechnologies',
#   'siddharthkp',
#   'biochemistries',
#   'Panzerfrank',
#   'srikanthkalinga',
#   'mlangsworth',
#   'cioreview',
#   'lrbarba',
#   'Siftedeu',
#   'marcelcutts',
#   'MichOConnell',
#   'NetzwerkI40',
#   'DataDudeCM',
#   'donaldkerr',
#   'schneider_chris',
#   'GlennSarti',
#   'rscharrer',
#   'liberation_data',
#   'jnilsson_se',
#   'davedemink',
#   'LewisGuess3',
#   'Danict89',
#   'hankamarketing',
#   'arjunattam',
#   'yworks',
#   'junior_java_web',
#   'mcguirl',
#   'ZelleTTY',
#   'alannakelly_ie',
#   'WeAreSolvaria',
#   'PhillyGraphDB',
#   'SemanticScholar',
#   'kojiannoura',
#   'otaviojava',
#   'cchilderhose',
#   'ReactDOM',
#   'ARTIKCONSULTING',
#   'dyanarose',
#   'n33nad',
#   'Mohamed83908616',
#   'yaravind',
#   'sokoltalk',
#   'EdPiairo',
#   'bdavis_dfw',
#   'Bigdatadimenson',
#   'FiniteIT',
#   '_wemu',
#   'wallingf',
#   'matteo80',
#   'JDKurz',
#   'FGRibreau',
#   'PinkProgramming',
#   'TheMrBlueprint',
#   'strickerconsult',
#   'bsoman3',
#   'SundayLavin',
#   'django_codek',
#   'cpan_new',
#   'markcichy',
#   'mark_farbrace',
#   'evanderburg',
#   'OliverMilke',
#   'SaurashtraNews',
#   'watsonstevenc',
#   'nid90',
#   'sixwing',
#   'DeveloperWebTV',
#   'baselogic',
#   'HackerNewsPosts',
#   'COLAjournal',
#   'BnBindu',
#   'VulmonFeeds',
#   'icymihn',
#   'CytByk',
#   'PunjabSamachar',
#   'changelog',
#   'BitfuryGroup',
#   'jvilledieu',
#   'Consip_Spa',
#   'ITSecurityNow',
#   'granvilleDSC',
#   'formfeuer',
#   'emilpersson',
#   'snootgirl',
#   'imsampro',
#   'johnstaveley',
#   'seanjregan',
#   'jrdemasi',
#   'ARC_Consulting',
#   'PanahEmad',
#   'Benjie',
#   'OptimalBI',
#   'according2jwest',
#   'Dkun47982438',
#   'krisnova',
#   '_masaka',
#   'PrograLanguages',
#   'PRTIMES_TECH',
#   'shaun_r_ray',
#   'PyDataMiami',
#   'zaddo',
#   'craigtaverner',
#   'GPTechfriendly',
#   'confluentinc',
#   'JAGLees',
#   'MsSammieRose',
#   'prondzyn',
#   'juanantoniobm',
#   'python__tut',
#   'richieajones1',
#   'datachick',
#   'peeterskris',
#   'mabraFoo',
#   'great2grassi',
#   'bobpoekert',
#   'Graphistry',
#   'C_as_in_Carl',
#   'raazozone',
#   'GoogleBrain5',
#   'ExonumPlatform',
#   'ifraixedes',
#   'dreduphd',
#   'MPLSTechEvents',
#   'pcrickard',
#   'datadanlarson',
#   'leovdd',
#   'sboswell',
#   'mikesparr',
#   'SpacedadUNI',
#   'webcode',
#   'fijiaaron',
#   'javatotto',
#   'jhilgerbc',
#   'vengerovski',
#   'iisyseki',
#   'adham_benhawy',
#   'RemlingerC',
#   'SWPlacementsIre',
#   'cbronline',
#   'm_pandian_s',
#   'blue_mile',
#   'Irish_TechNews',
#   'webAnalyste',
#   'HugoAndresMR',
#   'infinitary',
#   'aarontay',
#   'spyndutz',
#   'bloqafella',
#   'MrBWilms',
#   'WIngenieur',
#   'zhudigrandmoon',
#   'rheinjug',
#   'RealGophersShip',
#   'GregBufithis',
#   'JoukoHuismans',
#   'jerrong',
#   'heisedc',
#   'CharlesBrett',
#   'sandfoxthat',
#   'awsgeek',
#   'AlecSocial',
#   'AndreaBardone',
#   'remixerator',
#   'NathanEJBrown',
#   'zrail',
#   'andrewrgoss',
#   'kennekai',
#   'ConnectItpl',
#   'AlanPowiatowy',
#   'barberabrakel',
#   'micahstubbs',
#   'misterrios',
#   'PHPProgramming_',
#   'david_green_uk',
#   'michaelconlin10',
#   'hpgrahsl',
#   'dmatking',
#   'Un1v3rs0Z3r0',
#   'jugffm',
#   'data_guide',
#   'ScrapingWeb',
#   'fdiotalevi',
#   'g_labrousse',
#   'Scamper_Jones',
#   'gozermon',
#   'kpbird',
#   'No1Melman',
#   'DataJawn',
#   '_brodz_',
#   'SinghManpreet',
#   'PyDataDelhi',
#   'NewsFromBW',
#   'theitstrategist',
#   'Julian__Ford',
#   '_mangesh_tekale',
#   'KaiWaehner',
#   'annwitbrock',
#   'Dbcodes',
#   'johnkoetsier',
#   'logisima',
#   'bitnami',
#   'francoisgoube',
#   'BangBitTech',
#   'soichoosehim',
#   'ShintoLabs',
#   'nulladmin',
#   'PlanVol',
#   'lmeyerov',
#   'MosiMoradian',
#   'romain_francois',
#   'eugenplaton',
#   'thepeterdoyle',
#   'paskuvan',
#   'vertex_id',
#   'gaithoben',
#   'maestrejoseg',
#   'mmmgaber',
#   'arXiver',
#   'df00z',
#   'ok_grow',
#   'giftkugel',
#   'danielcantorna',
#   'AMULETAnalytics',
#   'tomitribe',
#   'TheGaryGibson',
#   'Ko_Ver',
#   'hn_bot_top1',
#   'freyduni',
#   'OpenSourceHolic',
#   'DataSpeaks',
#   'smugnier',
#   'menegidio',
#   'smuckwell',
#   'CRM_CWS_Cloud',
#   'AWS_Tutorialz',
#   'Sebsel',
#   'oss_csharp',
#   'david_das_neves',
#   'jaredcnance',
#   'vishivish18',
#   'PierreGuinault',
#   'shelajev',
#   'Vivek__95',
#   'BenPatrickWill',
#   'alain2sf',
#   'logicofjames',
#   'luannem',
#   'maxlarosa80',
#   'pintojoey',
#   'stpaquet',
#   'MarianaSSABA',
#   'jzperry',
#   'emilwidlund',
#   'dbkarthik',
#   'SmalkovVladilen',
#   'AnalyticsFrance',
#   'TheTroyLarson',
#   'simonleggsays',
#   'itamarhaber',
#   'andrewfnewman',
#   'ElizabethFdo',
#   'richiesgr',
#   'ClouderaAPAC',
#   'pregopresto',
#   'CSolutions_IE',
#   'kinkedoudid',
#   'polleywong',
#   'apache_fortress',
#   'RithyaLauv',
#   'ClubSignage',
#   'jcansdale',
#   'NotMedic',
#   'yassinm_tw',
#   'obonsignour',
#   'Matheus__PHN',
#   'skempe42',
#   'safkass',
#   'cyberthecaireQC',
#   'cackerman1',
#   'datacountry_ai',
#   'vCloud_Storage',
#   'aaronw_pb',
#   't_s_institute',
#   'elsoft74',
#   'AnoopKumarBhat',
#   'shelgesson',
#   'LDahg',
#   'mortazavi71',
#   'Penguin_Coders',
#   'Knolspeak',
#   'python_devv',
#   'GeoMahdi',
#   'ToferC',
#   'rahulsahay19',
#   'bluedonkey',
#   'forketyfork',
#   'EmreSevinc',
#   'emlynclay',
#   'ihackforfun',
#   'RichardMoorhead',
#   'ThisIs__Johnny',
#   'haagenhasle',
#   'ja_karman',
#   'TechGrupoZAP',
#   'jonashackt',
#   'golang_news',
#   'LinkMeJS',
#   'Nate_somewhere',
#   'rdiezv',
#   'sergio_grisa',
#   'eller82',
#   'Tkfm_M',
#   'datiobd',
#   'dbaManny',
#   'dsantarelli',
#   'boicy',
#   'rongsf',
#   'herrhelms',
#   'Raumzeitfalle',
#   'itsvit',
#   'liotier',
#   'Web_Dev_Robot',
#   'digityser',
#   'thobe',
#   'ggteksolutions',
#   'tanzidei',
#   'James_M_Tucker',
#   'h2o_tweets',
#   'ruettet',
#   'varunprime',
#   'MphisTechEvents',
#   'HaryanaDaily',
#   'cechode',
#   'JonnCallahan',
#   'webuproar',
#   'JustAHerb',
#   'fah7eem',
#   'BizTechBoost',
#   'mvallet91',
#   'adamcrussell',
#   'RonaldDamhof',
#   'dadoonet',
#   'Ben_Krug',
#   'JackVaughanatTT',
#   'ShubhamDeksto',
#   'hackernewsrobot',
#   'dongguangming',
#   'mikeydrum',
#   'jkwebtec',
#   'dantdr',
#   'sinitsin',
#   'arunpas97',
#   'cgdougm',
#   'grexe',
#   'high_fly2026',
#   'Anis_Adservio',
#   '_nicolemargaret',
#   'Hitachi_DE',
#   'RamseurANANT',
#   'norm_good',
#   'eudriscabrera',
#   'fabricioflores',
#   'imHealthy_2015',
#   'Y__Alnajjar',
#   'RichardPaul3',
#   'anitayorker',
#   'pyconsk',
#   'pirhoo',
#   'opentheboxbe',
#   'i_m_andrea',
#   'fratmelhylmaz',
#   'cip22',
#   'fbiville',
#   'warkolm',
#   'kuangkeng',
#   'MooglieTwitimon',
#   'thoweCH',
#   'talkingkotlin',
#   'crichey',
#   'DevOpsDaysPHX',
#   'NodeFan',
#   'mdmads_',
#   'Jonathon_Wright',
#   'salil',
#   'iamMrDuncan',
#   'pythoninfo',
#   'DeanWilliamsEY',
#   'chauhan_vin1',
#   'alicemazzy',
#   'tomo_thumb',
#   'LiveDataConcept',
#   'jreuben1',
#   '__rkaneko',
#   'detrio',
#   'neptanum',
#   'gbhorwood',
#   'pythontrending',
#   'SchoolDeveloper',
#   'bigdata_network',
#   ...},
#  {'GeekInfoNow'},
#  {'lio_deb'},
#  {'twosheeep1'},
#  {'1amageek',
#   '1ntegrale9',
#   '2017takeda',
#   '7omich',
#   'DaisukeTojo',
#   'FJKei',
#   'HimenoKairi',
#   'Kaito_Yoshitate',
#   'Kengo_TODA',
#   'KitaitiMakoto',
#   'KoukoMatsumoto',
#   'KzhtTkhs',
#   'Moririn47273285',
#   'OSS_News',
#   'OracleDev_JP',
#   'PG_kura',
#   'POSTDcc',
#   'P_tan',
#   'Quramy',
#   'R_STYLE',
#   'RyoAsakura1226',
#   'SightSeekerTw',
#   'T5uku5hi',
#   'TSB_KZK',
#   'TakahashiKat',
#   'TeraBytesMemory',
#   'Wp120_3238',
#   'Yasu_umi',
#   '__snow_rabbit__',
#   '_nabeen',
#   '_serinuntius',
#   'akira6592',
#   'akitomo_cs',
#   'amanoese',
#   'andreHiGasa',
#   'aoda',
#   'apstndb',
#   'beeyan08',
#   'blue_islands',
#   'bringer1092',
#   'bukaz54',
#   'cero_t',
#   'chrkwbr',
#   'classmethod',
#   'cloudsnow',
#   'codeout',
#   'cotton_desu',
#   'cp_tokyo_events',
#   'curry_on_a_rice',
#   'd0nchaaan',
#   'daiconnnnnnn',
#   'darthorimar',
#   'deeeet',
#   'dev_supisula',
#   'disney_Lady_Pg',
#   'dokokano_panda',
#   'enpedasi',
#   'enterprisezine',
#   'examstep',
#   'gaku_hiro',
#   'grimrose',
#   'haccht',
#   'harryharries861',
#   'hi86074659',
#   'him0net',
#   'hiromoon_428',
#   'hoishinxii',
#   'hrk0619',
#   'i_szyn',
#   'ike_dai',
#   'insomnyan',
#   'isyumi_net',
#   'iw_tatsu',
#   'janome_s',
#   'jbking',
#   'jdoiwork',
#   'jedipunkz',
#   'johtani',
#   'juntoku_y',
#   'junya',
#   'jwhaco',
#   'ka_ka_xyz',
#   'kabukawa',
#   'kbaba1001',
#   'keii1111',
#   'keke_moto',
#   'keyhs8',
#   'kimukou2628',
#   'kimutansk',
#   'kommy_mlnx',
#   'komo_fr',
#   'kompiro',
#   'kouwasi',
#   'koyakei',
#   'koyamauchi',
#   'kuwa_tw',
#   'kymmt90',
#   'letusfly85',
#   'linyows',
#   'lll_anna_lll',
#   'm4buya',
#   'ma2saka',
#   'maato',
#   'matsuu_zatsu',
#   'matt_zeus',
#   'mininobu',
#   'misakapon',
#   'mitsuhiro',
#   'miyamo_madoka',
#   'monochromegane',
#   'morihaya55',
#   'moririn9803',
#   'moris5321',
#   'moznion',
#   'mya_ake',
#   'narutaro',
#   'nikochan2k',
#   'niwatolli3',
#   'nnao45',
#   'nntsugu',
#   'nullue',
#   'ok_mozy',
#   'ora_club',
#   'oraryotas',
#   'oss_info',
#   'pg_son',
#   'prmnmbr_',
#   'qb0C80aE',
#   'rinosamakanata',
#   'rr250r_smr',
#   'ryoasu_107',
#   's01',
#   'sakapun',
#   'sect10n9',
#   'sh_0i3n07',
#   'shiget84',
#   'shin_tsujido',
#   'shinpei0213',
#   'shiraponsu',
#   'shirara1',
#   'smdmts',
#   'ssssssigma',
#   'stepan_ve',
#   'stereocat',
#   'substance626',
#   'suke083',
#   'syossan27',
#   't_marcus87',
#   'taisyoku_P',
#   'take3000',
#   'takeokunn',
#   'takezoen',
#   'tatakaba',
#   'tech_advent',
#   'tech_slideshare',
#   'toricls',
#   'tttamurat',
#   'tty_tkhs_ml',
#   'uehaj',
#   'utsumuki_neko',
#   'vaaaaanquish',
#   'water_boy_tokyo',
#   'wereyak',
#   'yasushia',
#   'yokatsuki',
#   'yoshidashingo',
#   'yosukehara',
#   'ysnr_ksm',
#   'yujiorama',
#   'yupeji',
#   'yurau75',
#   'yuw27b',
#   'zabbiozabbio'},
#  {'martinj06231870'},
#  {'DiscoveryMosti'},
#  {'9yen'},
#  {'TopTechSolution'},
#  {'fmeglar'},
#  {'composioco'},
#  {'RmwVamp'},
#  {'andre_andre_007'},
#  {'fbajri'},
#  {'aishulakshmi'},
#  {'DMZAsiaPacific', 'GARSmailes', 'PlusCoaching', 'RaedanExchange', 'csanki'},
#  {'hackernews100'},
#  {'JabalpurChronic'},
#  {'OneTwoFreee'},
#  {'GurgaonS'},
#  {'RhodeIslandChro'},
#  {'SmortiWalter'},
#  {'1Gerbs',
#   'Dave_Jonez_02',
#   'DevNullProd',
#   'HammerToe',
#   'Hodor',
#   'KevinKing64',
#   'MikeGlobTrends',
#   'Ocean_4549',
#   'Pavel_Escobar86',
#   'Prosatan666',
#   'XRPMedia',
#   'XRP_121',
#   'XRPeezy',
#   'XrpCenter',
#   'akrepisback',
#   'centurypointllc',
#   'luv2hodl',
#   'mindclimbing',
#   'thompsanator',
#   'xrpscan'},
#  {'doriath69'},
#  {'Wunderkidblog'},
#  {'_ericlimao'},
#  {'asdrgil'},
#  {'akiatoji'},
#  {'WorkCaryNC'},
#  {'TacticalTokens'},
#  {'amna_hira'},
#  {'_powerbuilder'},
#  {'AlchemySki'},
#  {'PhynoMyMentor'},
#  {'csabiu'},
#  {'BareillyMail'},
#  {'360WiseMedia'},
#  {'DigitalPsyche', 'RareButSerious'},
#  {'MCBE_Portal', 'ecila_vip', 'kazuemon_0602'},
#  {'IFFCNL'},
#  {'yodirkx'},
#  {'Darren_Mann'},
#  {'Gizlydeals'},
#  {'plwarre'},
#  {'bihranalytics'},
#  {'DominikLincer'},
#  {'righelp'},
#  {'Nagaland_News1'},
#  {'eroznama'},
#  {'HowrahNewsToday'},
#  {'CheesecakeLabs'},
#  {'Jiangning16'},
#  {'sameershelavale'},
#  {'WildeGio'},
#  {'SassyBDenise'},
#  {'klaasheek'},
#  {'hakandamar'},
#  {'natarajsasid'},
#  {'tigran_tv'},
#  {'rahularyan786'},
#  {'matsurisanv2'},
#  {'edgarmontalvo76'},
#  {'TomNwainwright'},
#  {'Mutiarasoftindo'},
#  {'am9gw'},
#  {'rzmpro'},
#  {'GoogleAlerts1'},
#  {'VijayS91403818'},
#  {'WisdomjobsH'},
#  {'anishgrandhi'},
#  {'btMatthew'},
#  {'VirineyaMr'},
#  {'825jp'},
#  {'ales85943804'},
#  {'frontendbook'},
#  {'cloud502'},
#  {'ignotamedia'},
#  {'livenewsstockma'},
#  {'NascarByJava'},
#  {'deadmilkman'},
#  {'im_not_enemy'},
#  {'ztztech'},
#  {'dot_Ri4'},
#  {'adamjennison'},
#  {'fusedat'},
#  {'malaybhatta'},
#  {'FuhStudium'},
#  {'RichmondNewsNow'},
#  {'soxamarin'},
#  {'MikeTheAggieKID'},
#  {'MandelaCS'},
#  {'ImFanky'},
#  {'King_Sloth95', 'liayeaaah', 'yasabdulkadir'},
#  {'iForexRobot'},
#  {'justinsmorgan'},
#  {'LudoLyon'},
#  {'codeqa_ja', 'codeqa_ko'},
#  {'ahmadajeb'},
#  {'Picante_Media'},
#  {'California_hr'},
#  {'EmploiBruxelles'},
#  {'nieuwejobs'},
#  {'saeedeldah'},
#  {'CanGovSciPubs'},
#  {'vdhJonas'},
#  {'sysdevmemor'},
#  {'senthil_hi'},
#  {'MoleBizMedia'},
#  {'typenullbot'},
#  {'Ebooksources1'},
#  {'newsvire1'},
#  {'JoostEaston'},
#  {'imohorianu'},
#  {'calorinesteps'},
#  {'Cekingx'},
#  {'God14Peace'},
#  {'boxong84', 'tinysong84'},
#  {'athul_karthik'},
#  {'FileMaker',
#   'FileMakerToday',
#   'FileMaker_NL',
#   'JeroenAarts',
#   'JorisAarts',
#   'ShawnGillisAFFI',
#   'agir',
#   'att_it_ude',
#   'clickworks_eu',
#   'didierdaglinckx',
#   'douglasalder',
#   'fmsummit',
#   'hedmanjohan77',
#   'tcolles73',
#   'vmenanno'},
#  {'ABNewswire'},
#  {'Whaley9ja'},
#  {'serebralfunding'},
#  {'threatmeter'},
#  {'GodColComputing'},
#  {'SaberX01'},
#  {'Sir_FredBanting'},
#  {'techstartupguy'},
#  {'EasternIndiaNew'},
#  {'Danomitez'},
#  {'aankitmishraa'},
#  {'MeerutReporter'},
#  {'EricMacLeod920'},
#  {'porkbelly369'},
#  {'StormMela'},
#  {'ttttt'},
#  {'isamarsa71'},
#  {'GayaHerald'},
#  {'ExploringBlock'},
#  {'HackerfallFeed'},
#  {'Osukarin'},
#  {'thekuwar'},
#  {'newstermer'},
#  {'rijin1230609'},
#  {'inventivaindia'},
#  {'HomesteadDev'},
#  {'MizoramMail'},
#  {'SecurityNews'},
#  {'WeekServices'},
#  {'sgroenendal'},
#  {'DaraWehmeyer'},
#  {'repo_go'},
#  {'magrid_prisca'},
#  {'JobOfferUSA'},
#  {'thedpsadvisors'},
#  {'michael_l_heuer'},
#  {'aspnetissues', 'dotnetissues'},
#  {'RPubsHotEntry', 'RPubsRecent'},
#  {'fancyfaceza'},
#  {'wqv5mbs14'},
#  {'Alastairkretser'},
#  {'JKHeadlines'},
#  {'Saikat475k'},
#  {'softnix'},
#  {'moleytc'},
#  {'LesCNow'},
#  {'trendnewsdot'},
#  {'OnlineInstruct1'},
#  {'AlexaAvitto'},
#  {'freelanceOffres'},
#  {'Brizzysport'},
#  {'NewDelhiNews1'},
#  {'cguija'},
#  {'Babaranwar9'},
#  {'TechNewsexpert'},
#  {'Rajasthan_NP'},
#  {'SnaptechNews'},
#  {'m_dubbs'},
#  {'ZwoSchlagzeilen'},
#  {'kitman_yiu'},
#  {'adeosecurity'},
#  {'sbmelton'},
#  {'jaorr95'},
#  {'The_one_E'},
#  {'Jamar_100'},
#  {'SwissBankMane'},
#  {'fiweh'},
#  {'Stonewater20'},
#  {'redfields'},
#  {'Swahilipages'},
#  {'Crystal_R_Brodi', 'ledrew'},
#  {'AlisonCYoung88'},
#  {'Eroskhan1211'},
#  {'siobhansabino'},
#  {'Semtori'},
#  {'httjinsoul'},
#  {'purelyfast'},
#  {'financialbuzz'},
#  {'99udemy'},
#  {'AjithVerma'},
#  {'MENA_Britain'},
#  {'RankZoom'},
#  {'Saliga10'},
#  {'haunthaus'},
#  {'vivasasvegas'},
#  {'DineshMaheshwri'},
#  {'lozhn'},
#  {'RPQ48'},
#  {'iangodman'},
#  {'bootusb1'},
#  {'ParicioRafa'},
#  {'CrosswaterJob'},
#  {'42clientsTim'},
#  {'ojcst_journal'},
#  {'freelancingphil'},
#  {'lingamarlas'},
#  {'lieberman__'},
#  {'PansehTsewole1'},
#  {'latestcanada'},
#  {'bfkese'},
#  {'WorkLynnMA'},
#  {'timaccenture'},
#  {'CecileRay', 'NgoImpact'},
#  {'seeklogo'},
#  {'KenyanTraffic', 'ThikaTowntoday', 'at254Kenya'},
#  {'wowebookorg'},
#  {'NewsMadurai'},
#  {'wildrot'},
#  {'BeerbliotecaApp'},
#  {'SpiritOfTheJag'},
#  {'christianebuddy'},
#  {'Lifina'},
#  {'pls_ss'},
#  {'WtmMao'},
#  {'Stock_Market_Pr', 'feed_stocks'},
#  {'freshgoodsuk'},
#  {'chrisdpeters'},
#  {'bygcho'},
#  {'AirdropsCoin1'},
#  {'TwkalC'},
#  {'danielzairick'},
#  {'marimoaki'},
#  {'APHeadlines1'},
#  {'Node_Geek'},
#  {'garyskeete'},
#  {'ollorinko'},
#  {'GlobeTechReport'},
#  {'GiridihJournal'},
#  {'PerpustakaanITS'},
#  {'rabah_wael'},
#  {'manishti2004'},
#  {'SlicesSLU'},
#  {'RandWikipediaFr'},
#  {'youngs_suh'},
#  {'psclgllt'},
#  {'fsudmann'},
#  {'janisreading'},
#  {'LifewithAI'},
#  {'TechNewsFast'},
#  {'lontchi'},
#  {'oolpublishing'},
#  {'CookMyProject'},
#  {'websiteprousa'},
#  {'hdyhrosli'},
#  {'windenergysci'},
#  {'pandyavaibh'},
#  {'ingridcervin'},
#  {'CGRBOregonState'},
#  {'CloudReputation'},
#  {'BilaspurNewsFla'},
#  {'newsv24'},
#  {'blendedio'},
#  {'Photoshop__Tut'},
#  {'PhreeTechltd'},
#  {'feedpushr'},
#  {'fabianito63'},
#  {'BigSeanSSB'},
#  {'FrancoLisi'},
#  {'Dila66294955'},
#  {'Brainstrust_HQ'},
#  {'1Wisdomjobs'},
#  {'jazzdrummer420'},
#  {'yeti_in_a_box'},
#  {'getvantagepoint'},
#  {'thesunshinerepo'},
#  {'BigDataSpace'},
#  {'McCartn_ebooks'},
#  {'brussels_event'},
#  {'vo3xel'},
#  {'ReeceOBryan'},
#  {'douglasanalista'},
#  {'cichy_de'},
#  {'Angelic83007262'},
#  {'kchalise'},
#  {'kikuzone'},
#  {'shrideepghogare'},
#  {'RoberttBertton'},
#  {'kentfordev'},
#  {'Juliaat05'},
#  {'AurangabadMagaz'},
#  {'CrweWorld'},
#  {'NYUSternFC'},
#  {'pol_ins'},
#  {'corywcordell'},
#  {'Toshakins'},
#  {'myassirullah'},
#  {'isbc_rus'},
#  {'prabhinmp'},
#  {'DarkCreekWay'},
#  {'micheseco'},
#  {'tvalentenc'},
#  {'visceralnair'},
#  {'BharatDaily'},
#  {'storewithcoupon'},
#  {'JobzBot'},
#  {'avhk47'},
#  {'Flip101420'},
#  {'AmricaNascimen2'},
#  {'arrowsmith'},
#  {'anitha_perumal'},
#  {'Dsanwoola'},
#  {'fcggamou'},
#  {'PhoNetworks'},
#  {'Autotestdrivers'},
#  {'knbzyh'},
#  {'ProfessorFlossy'},
#  {'kaisarhasansohe'},
#  {'pcs31493'},
#  {'AnkaaEngine'},
#  {'A_Zbookstore'},
#  {'azharjamal'},
#  {'f10ck3'},
#  {'ImranOnline_net'},
#  {'techrdv'},
#  {'lb_greens'},
#  {'BrentonPoke'},
#  {'jsringo'},
#  {'travislepp'},
#  {'pmiozzi'},
#  {'hacklinesapp'},
#  {'DevelopKitchen'},
#  {'JohnAngel1977'},
#  {'DeepFinds'},
#  {'itlize'},
#  {'vruchtvet'},
#  {'abdellah19922'},
#  {'gautamkalal'},
#  {'NoidaChronicle'},
#  {'it_malibu'},
#  {'alphainspire'},
#  {'stargao3'},
#  {'facttob'},
#  {'aaaa888824'},
#  {'pvmarketing'},
#  {'sanopoyo'},
#  {'Xpacer_'},
#  {'Geezwild'},
#  {'ghafoor2018'},
#  {'InfoManipur'},
#  {'Hauxon'},
#  {'CrmJoy'},
#  {'dearappauthors'},
#  {'ajdiangelus'},
#  {'tambovcev99'},
#  {'marketnewslates'},
#  {'DumaOctavian'},
#  {'daniellam83'},
#  {'DiabetesTweets'},
#  {'JCI_SecuritySME'},
#  {'BetDollars'},
#  {'NTKRNow'},
#  {'jobs_in_boston'},
#  {'MKhumanthem'},
#  {'naebumaye'},
#  {'gakogakotto2'},
#  {'softwarenews42'},
#  {'Lt_Walker9'},
#  {'SE_Barbell'},
#  {'JayEntrust'},
#  {'JobsAshford'},
#  {'MichaelOstuni'},
#  {'w4w3r'},
#  {'AndrzejRama'},
#  {'naderys'},
#  {'nexgespl'},
#  {'husenpb'},
#  {'aepiphanni'},
#  {'KathiawadToday'},
#  {'Ahmed777962'},
#  {'Rate1tter'},
#  {'5th_ghostbuster'},
#  {'TheDotsGroup'},
#  {'FXBAUD'},
#  {'linuxeden_com'},
#  {'DefeatNCD'},
#  {'chaital14315682'},
#  {'_mommarobyn'},
#  {'muliadi_ii'},
#  {'Rishilious22333'},
#  {'phillyinformer'},
#  {'lexxsoft'},
#  {'DruckereiCHBeck'},
#  {'AssamReporter'},
#  {'edmondying'},
#  {'CharBirch92'},
#  {'Cryptonic_Y4n'},
#  {'techcrown03'},
#  {'rasam260'},
#  {'triboland'},
#  {'lowterrain'},
#  {'Rohith62653700'},
#  {'Mpanga96'},
#  {'tee_mars3'},
#  {'oberoi_rohu'},
#  {'Hire_Atl'},
#  {'DragonHasFlown'},
#  {'17lorelei76'},
#  {'kardsen'},
#  {'newsmanofindia'},
#  {'morodog'},
#  {'OracleSql_JP'},
#  {'mitsunoir'},
#  {'worldat247'},
#  {'binetou_gueye'},
#  {'PREcho_de'},
#  {'MrMasudAhmad'},
#  {'AndreasTully'},
#  {'PuneMagazine'},
#  {'pangenomepapers'},
#  {'Jonathonsciola'},
#  {'tracygloverj'},
#  {'vrungta'},
#  {'toshi_tuki'},
#  {'Trialanderror_v'},
#  {'StephanHakan'},
#  {'pankazjosh'},
#  {'risksecure'},
#  {'MAT_Updates'},
#  {'knowlix'},
#  {'dunyawatm'},
#  {'wfrdasilva'},
#  {'DialysisSaves'},
#  {'notimeoff'},
#  {'lingufishcom'},
#  {'NewsFromSPI'},
#  {'CoreyLapka'},
#  {'punga127'},
#  {'nani938'},
#  {'rhetonik'},
#  {'PeterbMangan'},
#  {'gavinpiper108'},
#  {'KumarV61'},
#  {'masaun2551'},
#  {'PANrecruiter'},
#  {'natosepia'},
#  {'drsenri'},
#  {'Corporate88'},
#  {'naixent'},
#  {'CloudGuru6'},
#  {'Amir_Gh97'},
#  {'codehoven'},
#  {'Yan15730195'},
#  {'MacksofyT'},
#  {'WhitepapersOl'},
#  {'tatsuzawa'},
#  {'GoaHeadlines1'},
#  {'RadioUdeG'},
#  {'coco_air'},
#  {'Vaclavp_77'},
#  {'aldaz'},
#  {'ThOneUpKID1'},
#  {'trinity_digest'},
#  {'ViterbiCareers', 'ysoto1'},
#  {'luthermolvera'},
#  {'etoile_cr'},
#  {'HedgeBz', 'pythontic_'},
#  {'chemical_eLii'},
#  {'Fasteners'},
#  {'MOHAMMEDxHASSAN'},
#  {'0Mtbuzzer'},
#  {'Jeannette_Bot'},
#  {'IllinoisRecruit'},
#  {'thiruvananthap1'},
#  {'froshloaded'},
#  {'ITmixCZ'},
#  {'HomeDreamz'},
#  {'kentuckynewsdes', 'lansingnewsnow'},
#  {'jonathanbracam'},
#  {'KathiFajardo'},
#  {'anxiously0307'},
#  {'domainnamesnz'},
#  {'InfoTechnology3'},
#  {'FoundryNewsBot'},
#  {'mtl_ecommerce'},
#  {'chimwemwepaul'},
#  {'arpinstu'},
#  {'YUHKEINCT'},
#  {'eprnetwork'},
#  {'jelly_words'},
#  {'larsen693'},
#  {'cstromblad'},
#  {'Rafael_Asanov'},
#  {'lou_hou'},
#  {'Corey4Progress'},
#  {'APX3D_Printing'},
#  {'project_ltd'},
#  {'moniquenini'},
#  {'Simon_Activist'},
#  {'talk_to_myself7'},
#  {'inspirisys'},
#  {'CryptoLegion'},
#  {'serujio_kmdhe'},
#  {'JobsTemeculaCA'},
#  {'LaughingAoi'},
#  {'menomale_che'},
#  {'nuncapops'},
#  {'ecomputerbooks'},
#  {'AutomationForum'},
#  {'DispurNewsFlash'},
#  {'UBAffiliates'},
#  {'TCMarcum'},
#  {'ZHSLLC'},
#  {'matthewhall78'},
#  {'Cyberjinio'},
#  {'RanchiNewsDesk'},
#  {'gbuckholtz'},
#  {'atom_HeV'},
#  {'EasyPC_in'},
#  {'doserre'},
#  {'AdeolaHadey'},
#  {'GilbertLeconte'},
#  {'GiveInfoMe1'},
#  {'TR_network', 'Toprogrammer'},
#  {'orkin'},
#  {'letisales'},
#  {'TheWebGlobal'},
#  {'OS__Expert'},
#  {'barlocast'},
#  {'remotepeople'},
#  {'DisyDev'},
#  {'HendrixsMoney'},
#  {'Kafka'},
#  {'megha_prn'},
#  {'lovingcatz'},
#  {'KudtarkarParul'},
#  {'fundrais123'},
#  {'brentbisso'},
#  {'MoraAleja55'},
#  {'crmcoach'},
#  {'legnavegroup'},
#  {'MOHIO_GmbH'},
#  {'A10_APU'},
#  {'Trew30_'},
#  {'ambandla'},
#  {'Milner801'},
#  {'barbyware'},
#  {'anyhows_'},
#  {'ItssKansai'},
#  {'DPProfessionals'},
#  {'charles_azar'},
#  {'fininsyn'},
#  {'andryukhin'},
#  {'ChronLaw'},
#  {'SinghadMekha'},
#  {'joemoukarzelone'},
#  {'teamclerk'},
#  {'jenifferiulius'},
#  {'tignear'},
#  {'linksightsio'},
#  {'nighguy'},
#  {'theTrueObserver'},
#  {'TwkIshii'},
#  {'aceouterspace'},
#  {'SkiBuni'},
#  {'echojs2'},
#  {'NiravPatel0204'},
#  {'twjoshua'},
#  {'Browsify'},
#  {'NicoleCheaven'},
#  {'WardCorbett'},
#  {'KhraisNoor'},
#  {'elitorr61842801'},
#  {'m_afatah'},
#  {'MyAlliesNews'},
#  {'SofiaITC'},
#  {'swankylynx'},
#  {'khalkeus3d'},
#  {'DigitalDownloa4'},
#  {'imoff333'},
#  {'Hshmear84'},
#  {'mikereys_sag'},
#  {'karaszewicz'},
#  {'MixMax123456'},
#  {'StackBounty'},
#  {'mrclydecarty'},
#  {'DelhiToday1'},
#  {'node_program'},
#  {'collegeprozheh'},
#  {'wakajobs'},
#  {'harbingertimes'},
#  {'DmitryShaman'},
#  {'Patachoup'},
#  {'NanyBKK'},
#  {'CounselUpdates'},
#  {'zkalvi'},
#  {'tribes_ai'},
#  {'daryna_shu'},
#  {'analysees'},
#  {'Making_Science_'},
#  {'BigData_TT'},
#  {'ourbennie'},
#  {'AlexPorumbel'},
#  {'MuawiaTechno'},
#  {'webready_se'},
#  {'h2onolan'},
#  {'doctorSturza'},
#  {'Fujitsu_FJCT'},
#  {'jperezdelolmo'},
#  {'1001tweetstest'},
#  {'benish369'},
#  {'Tibo_st'},
#  {'grepdev'},
#  {'SpicaTerrible_'},
#  {'yaxye2006'},
#  {'mpdrsn'},
#  {'D0m1s0l'},
#  {'tammyvwyatt'},
#  {'janeurby'},
#  {'ErieMom'},
#  {'JammuJournal'},
#  {'robertopliegor'},
#  {'serfusE_'},
#  {'JamshedpurRepor'},
#  {'NCROnlineNews'},
#  {'jjonisius'},
#  {'ForestWiki', 'PythonLinks'},
#  {'ictjob_1st_job'},
#  {'Madhuri01715'},
#  {'NagpurNewsDesk'},
#  {'HNTopStories'},
#  {'andreaslindner'},
#  {'marketemia'},
#  {'GasMarketing5'},
#  {'AhamPiyush'},
#  {'KeralaDaily1'},
#  {'MIRresearch'},
#  {'amico_nick'},
#  {'TheAndroid2011'},
#  {'davy_duboy'},
#  {'hoconinfo'},
#  {'JWeee'},
#  {'WFranceL'},
#  {'BorkowskMarcin'},
#  {'myshopzeemart'},
#  {'LPBoyer09'},
#  {'PDFviewerForWp'},
#  {'vikatakavi11'},
#  {'Rvgautam40RAVI'},
#  {'travailbelgique'},
#  {'estranhow', 'leonardodna'},
#  {'Tripura_News'},
#  {'technewspr'},
#  {'GadgetJoseph'},
#  {'unlikeanything'},
#  {'GustiiMCBA'},
#  {'BhubaneswarNew1'},
#  {'yoshieda_mn'},
#  {'ben_thijssen'},
#  {'brokoh1'},
#  {'nesoxy'},
#  {'HalmagyiCsaba'},
#  {'SnehaCh93683369'},
#  {'Avtora', 'social_pipe'},
#  {'SophisticatedCT'},
#  {'_nove_nove_'},
#  {'DeborahRoszell'},
#  {'OnlinePrNew'},
#  {'TechKnights_UCF'},
#  {'atoast2toast'},
#  {'tupples'},
#  {'CloudTenIT'},
#  {'motivasyonbuk'},
#  {'Viropera'},
#  {'techieappy'},
#  {'NHMeetings'},
#  {'itotto0205'},
#  {'b4dcode'},
#  {'Lingam40670559'},
#  {'Ahmadanii2'},
#  {'rsoftsolution'},
#  {'mint398'},
#  {'TheSmartIT'},
#  {'StoreConsulting'},
#  {'TheWiseFool4'},
#  {'acilnumara_uk'},
#  {'Paddy_Owens66'},
#  {'Pyenews2'},
#  {'JobsLowellMA'},
#  {'isabela2599'},
#  {'Sonya__Briggs'},
#  {'deeptodive', 'illusiontec'},
#  {'asapdiablo1'},
#  {'anderso62095558'},
#  {'4MrKW'},
#  {'leonardonam'},
#  {'mparkerCSI'},
#  {'TechPlot'},
#  {'AndhraPradeshJo'},
#  {'trevars'},
#  {'netmobz'},
#  {'HyperedgeEmbed'},
#  {'Ohionewsdesk', 'Oklahomacityhea'},
#  {'san_jose__jobs'},
#  {'acronymlister'},
#  {'KrzysiekRichter'},
#  {'tinafanson1124'},
#  {'XmarketReports'},
#  {'RaipurDaily'},
#  {'tennis6399'},
#  {'oss_sh'},
#  {'Cleora_Kramer'},
#  {'TechNewsJunkies'},
#  {'AphnoMarketing'},
#  {'jhleebitninene1'},
#  {'BasslKoukash'},
#  {'MonkOnDMT'},
#  {'suduo1233'},
#  {'OneBaldMan'},
#  {'Ntou4', 'tetoran6'},
#  {'AnaLaur15266130'},
#  {'Reisemate'},
#  {'stepik_reviews'},
#  {'BundelkhandOJ'},
#  {'BangaloreSamach'},
#  {'AmosTrack'},
#  {'ucl_discovery'},
#  {'noris_dev'},
#  {'odia_reports'},
#  {'Jai_Cilento'},
#  {'reachgilly'},
#  {'kawaguchi_com'},
#  {'besttechtrade'},
#  {'viqi_efendi'},
#  {'DreslerKlarissa'},
#  {'Photoshop_4u_'},
#  {'JAX_TechEvents'},
#  {'IlyaKomendantov'},
#  {'ruanchaves93'},
#  {'BlakeTrinityQu1'},
#  {'lyrixx_rss'},
#  {'TaxActPro'},
#  {'callennartsson'},
#  {'nurfawaiq'},
#  {'HaysDigiJobsUKI'},
#  {'parvezkhusro'},
#  {'RichardThoming'},
#  {'GazonArtificiel'},
#  {'storminwong'},
#  {'ashwinisundar', 'uftjob'},
#  {'Hiring_Atl'},
#  {'supercilious_fa'},
#  {'soladime_piece'},
#  {'entrepreneur_cm'},
#  {'talhatarik'},
#  {'jiayoulixu'},
#  {'LemonAnt'},
#  {'NMEtoday'},
#  {'PhilSallaway'},
#  {'claire83277378'},
#  {'123trabajo'},
#  {'VadodaraNews'},
#  {'thebyrdlab'},
#  {'objectofpower'},
#  {'IndoreOnlineJou'},
#  {'MarathaHeadline'},
#  {'MonjuSarder'},
#  {'continentspirit'},
#  {'XTechNewsV2'},
#  {'clr_develop'},
#  {'BusinessTrumpet'},
#  {'HaridwarToday'},
#  {'KSD_research'},
#  {'jhu_ai'},
#  {'prdpXbot'},
#  {'daviddryannn'},
#  {'SOMESH505'},
#  {'usamaofkarachi'},
#  {'IndiaNewsMagazi'},
#  {'WisdomjobsS'},
#  {'adster85'},
#  {'caquele_'},
#  {'AlexOpsAI'},
#  {'spstrasser'},
#  {'thephillirodney'},
#  {'dekdclubja'},
#  {'RighteousCrone'},
#  {'randomhub_'},
#  {'innocentinforma'},
#  {'GHasselwander'},
#  {'enrique_larriba'},
#  {'xjzhou'},
#  {'KohimaNewsPaper'},
#  {'recinet'},
#  {'AsaShinonome'},
#  {'Geeksarefunny'},
#  {'build_trumpwall'},
#  {'MurrietaCAJobs'},
#  {'mukundkmishra'},
#  {'Infoshoc'},
#  {'sahdevt'},
#  {'Ric9871Ric'},
#  {'Jesse_V_Burke'},
#  {'AmbalaHerald'},
#  {'ZoricaBel'},
#  {'uijft'},
#  {'Fumon'},
#  {'themuradonian'},
#  {'aka_BlackBadger'},
#  {'Mark20004DC'},
#  {'takerui'},
#  {'RhiscoGroup'},
#  {'HankinsSusanna'},
#  {'CheekDots'},
#  {'edyrmonroym'},
#  {'Jdking1920'},
#  {'ExactOptionPick'},
#  {'KoutsounisV'},
#  {'theresa_ehlen'},
#  {'BhagalpurToday1'},
#  {'Shulab'},
#  {'RadhikaKaruturi'},
#  {'stefanialevanti'},
#  {'jskim007961'},
#  {'Camille_OS'},
#  {'Malvatronics'},
#  {'EagleStarNET'},
#  {'KallelSaoussan'},
#  {'BESTWarszawa'},
#  {'bambillio'},
#  {'SimiPam_'},
#  {'victorjuliord'},
#  {'Techset4'},
#  {'ShariBermanATL'},
#  {'wicem'},
#  {'ArashRahimian'},
#  {'ahotdiscount'},
#  {'kodkneg'},
#  {'kumar70011'},
#  {'digitallifest10'},
#  {'FlatL1ne'},
#  {'LaravelPackages'},
#  {'DiabetesShare'},
#  {'PanipatHeadline'},
#  {'butchclark5'},
#  {'YassinBIBI5'},
#  {'AsagiriDesign'},
#  {'MNoorFawi'},
#  {'fsdqui'},
#  {'rhcp1010'},
#  {'LochaberLocal'},
#  {'kabochallah'},
#  {'zennie_fic'},
#  {'antony_wijay'},
#  {'1TheBlessed'},
#  {'anshu_kandhari'},
#  {'mdjubair_me'},
#  {'CryptoDaniella'},
#  {'fusercan'},
#  {'simulevski'},
#  {'natamvo'},
#  {'sajjadkazemi10'},
#  {'TheChestnutPost'},
#  {'fitditcorps'},
#  {'GetDataIO'},
#  {'boundatacamp'},
#  {'teknoteriyak'},
#  {'viqdy'},
#  {'AstrorEnales'},
#  {'LucasCollege'},
#  {'zientekglobal'},
#  {'WallyWave'},
#  {'KolkataNToday'},
#  {'aasisvinayak'},
#  {'Mrr_Zo'},
#  {'MaharashtraHera'},
#  {'Azim_Palmer'},
#  {'1clickdeploy'}]
